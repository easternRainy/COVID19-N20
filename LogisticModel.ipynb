# %% [markdown]
# # COVID-19 Data Analysis

# %%
from utils import *
from utils.paths import *
import utils.paths as p
from utils.plot import *
from utils.logistic_curve import *

# %% [markdown]
# ## Baseline Model: Logistic Regression

# %%
create_paths("DateWorld")
country = "US"
X_FIELD = "tagged_day"
Y_FIELD = "confirmed"
# test_size, percentage of test size
# diff, train_error - test_error
# train_error
# test_error
# a, b,c parameters of logistic curve

# parameters: (country, picture_output_path, X_FIELD, Y_FIELD)
test_size,diff,sol,train_error,test_error,a,b,c = plot_logistic(country, p.LR, X_FIELD, Y_FIELD)
# Out:
# /Users/zhousicheng/Projects/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:808: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 194,9.28904663356809,53.421384858156976,1355896.338078915
# DateWorld/2020-05-08/Analysis/LogisticRegression/US.jpg

# %%
create_paths("DateWorld")
country = "US"
X_FIELD = "tagged_day"
Y_FIELD = "deaths"
test_size,diff,sol,train_error,test_error,a,b,c = plot_logistic(country, p.LR, X_FIELD, Y_FIELD)
# Out:
# /Users/zhousicheng/Dropbox/Document/2019/20190821-USF/Term 2/CS640_Bioinformatics/COVID19-N20/utils/logistic_curve.py:23: RuntimeWarning: divide by zero encountered in double_scalars
#   tmp =  [np.power((a-b)/b, 2) for a, b in zip(y_pred, y_test)]
# /Users/zhousicheng/Dropbox/Document/2019/20190821-USF/Term 2/CS640_Bioinformatics/COVID19-N20/utils/logistic_curve.py:54: RuntimeWarning: invalid value encountered in double_scalars
#   diff = abs(train_error - test_error)
# /Users/zhousicheng/Dropbox/Document/2019/20190821-USF/Term 2/CS640_Bioinformatics/COVID19-N20/utils/logistic_curve.py:20: RuntimeWarning: overflow encountered in exp
#   return c/(1 + np.exp(-(x-b)/a))
# 164,7.8292426463294325,55.12160531534503,77807.0645578225
# DateWorld/2020-05-08/Analysis/LogisticRegression/US.jpg

# %%
create_paths("DateUS")
state = "California"
X_FIELD = "tagged_day"
Y_FIELD = "confirmed"
test_size,diff,sol,train_error,test_error,a,b,c = plot_logistic(state, p.LR, X_FIELD, Y_FIELD)
# Out:
# /Users/zhousicheng/Projects/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:808: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# /Users/zhousicheng/Dropbox/Document/2019/20190821-USF/Term 2/CS640_Bioinformatics/COVID19-N20/utils/logistic_curve.py:20: RuntimeWarning: overflow encountered in exp
#   return c/(1 + np.exp(-(x-b)/a))
# 184,9.67920997465712,58.773871421243626,65580.14328049507
# DateUS/2020-05-08/Analysis/LogisticRegression/California.jpg

# %%
create_paths("DateUS")
state = "California"
X_FIELD = "tagged_day"
Y_FIELD = "deaths"
test_size,diff,sol,train_error,test_error,a,b,c = plot_logistic(state, p.LR, X_FIELD, Y_FIELD)
# Out:
# /Users/zhousicheng/Dropbox/Document/2019/20190821-USF/Term 2/CS640_Bioinformatics/COVID19-N20/utils/logistic_curve.py:23: RuntimeWarning: divide by zero encountered in double_scalars
#   tmp =  [np.power((a-b)/b, 2) for a, b in zip(y_pred, y_test)]
# /Users/zhousicheng/Dropbox/Document/2019/20190821-USF/Term 2/CS640_Bioinformatics/COVID19-N20/utils/logistic_curve.py:54: RuntimeWarning: invalid value encountered in double_scalars
#   diff = abs(train_error - test_error)
# /Users/zhousicheng/Projects/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:808: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 133,8.580415587644215,62.793238894657414,2958.7689101327637
# DateUS/2020-05-08/Analysis/LogisticRegression/California.jpg
# /Users/zhousicheng/Dropbox/Document/2019/20190821-USF/Term 2/CS640_Bioinformatics/COVID19-N20/utils/logistic_curve.py:81: RuntimeWarning: invalid value encountered in double_scalars
#   return test_size,train_error-test_error,sol,train_error,test_error,a,b,c
