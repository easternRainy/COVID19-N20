# %% [markdown]
# # COVID-19 Project Bioinformatics

# %% [markdown]
# ### Import Dependencies

# %%
import os
os.chdir("../")
import sys
sys.path.insert(0, ".")

from utils import *
from utils.paths import *
import utils.paths as p
from utils.plot import *

# %%
create_paths("DateWorld")

# %% [markdown]
# ### Selected Countries in research

# %%
countries, index_country, country_index = get_countries()

# %%
selected_countries = [174,36,23,78,154,156,175,84,65,163,160,8,90,150,86,32]

# %%
for c in selected_countries:
    print(index_country[c])
# Out:
# US
# China
# Brazil
# Iceland
# Slovenia
# South Africa
# Uganda
# Israel
# Georgia
# Switzerland
# Sudan
# Australia
# Kenya
# Seychelles
# Jamaica
# Canada

# %% [markdown]
# #### Cumulative cases since N=20

# %%
plot_cumulative_multi_country(selected_countries)

# %% [markdown]
# #### New Daily Comfirmed Case since N=20

# %%
plot_new_confirmed_multi_country(selected_countries)

# %% [markdown]
# #### Cumulative Deaths since N=20

# %%
plot_deaths_multi_country(selected_countries)

# %% [markdown]
# #### Daily Confirmed Cases vs Daily Death Cases since N=20

# %%
plot_new_confirmed_new_deaths_country(selected_countries[0])

# %%
plot_new_confirmed_new_deaths_country(selected_countries[2])

# %%
plot_new_confirmed_new_deaths_country(selected_countries[3])

# %%
plot_new_confirmed_new_deaths_country(selected_countries[4])

# %%
plot_new_confirmed_new_deaths_country(selected_countries[5])

# %%
plot_new_confirmed_new_deaths_country(selected_countries[6])

# %%
plot_new_confirmed_new_deaths_country(selected_countries[7])

# %%
plot_new_confirmed_new_deaths_country(selected_countries[8])

# %%
plot_new_confirmed_new_deaths_country(selected_countries[9])

# %%
plot_new_confirmed_new_deaths_country(selected_countries[10])

# %%
plot_new_confirmed_new_deaths_country(selected_countries[11])

# %%
plot_new_confirmed_new_deaths_country(selected_countries[12])

# %%
plot_new_confirmed_new_deaths_country(selected_countries[13])

# %%
plot_new_confirmed_new_deaths_country(selected_countries[14])

# %%
plot_new_confirmed_new_deaths_country(selected_countries[15])

# %% [markdown]
# ### Selected US States in research

# %%
create_paths("DateUS")

# %%
states, index_state, state_index = get_us_states()

# %%
selected_states = [0,1,5,34,36]

# %%
plot_cumulative_multi_state(selected_states)

# %%
plot_new_confirmed_multi_state(selected_states)

# %%
plot_deaths_multi_state(selected_states)

# %%
plot_new_confirmed_new_deaths_state(selected_states[0])

# %%
plot_new_confirmed_new_deaths_state(selected_states[1])

# %%
plot_new_confirmed_new_deaths_state(selected_states[2])

# %%
plot_new_confirmed_new_deaths_state(selected_states[3])

# %%
plot_new_confirmed_new_deaths_state(selected_states[4])

# %% [markdown]
# # Insight
# - logistic model is suitable to predict the future
# - there is a peak difference between new confirmed and new deaths
