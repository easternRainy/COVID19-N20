# %% [markdown]
# # COVID-19 Data Analysis

# %%
import os
os.chdir("../")
import sys
sys.path.insert(0, ".")
from utils import *
from utils.paths import *
import utils.paths as p
from utils.plot import *
from utils.logistic_curve import *

# %% [markdown]
# ## Baseline Model: Logistic Regression

# %%
create_paths("DateWorld")
country = "US"
X_FIELD = "tagged_day"
Y_FIELD = "confirmed"
# test_size, percentage of test size
# diff, train_error - test_error
# train_error
# test_error
# a, b,c parameters of logistic curve

# parameters: (country, picture_output_path, X_FIELD, Y_FIELD)
test_size,diff,sol,train_error,test_error,a,b,c = plot_logistic(country, p.LR, X_FIELD, Y_FIELD)
# Out:
# ./utils/logistic_curve.py:20: RuntimeWarning: overflow encountered in exp
#   return c/(1 + np.exp(-(x-b)/a))
# /Users/zhousicheng/Projects/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:808: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 920,41.7949806568373,156.00145735176835,9100886.10376062
# DateWorld/2020-09-08/Analysis/LogisticRegression/US.jpg

# %%
create_paths("DateWorld")
country = "US"
X_FIELD = "tagged_day"
Y_FIELD = "deaths"
test_size,diff,sol,train_error,test_error,a,b,c = plot_logistic(country, p.LR, X_FIELD, Y_FIELD)
# Out:
# 423,27.519202023985784,82.34465658035582,171352.7203359737
# DateWorld/2020-09-08/Analysis/LogisticRegression/US.jpg
# ./utils/logistic_curve.py:20: RuntimeWarning: overflow encountered in exp
#   return c/(1 + np.exp(-(x-b)/a))

# %%
create_paths("DateUS")
state = "California"
X_FIELD = "tagged_day"
Y_FIELD = "confirmed"
test_size,diff,sol,train_error,test_error,a,b,c = plot_logistic(state, p.LR, X_FIELD, Y_FIELD)
# Out:
# 561,28.451163428275972,160.36471182672804,944939.7183250239
# DateUS/2020-09-08/Analysis/LogisticRegression/California.jpg

# %%
create_paths("DateUS")
state = "California"
X_FIELD = "tagged_day"
Y_FIELD = "deaths"
test_size,diff,sol,train_error,test_error,a,b,c = plot_logistic(state, p.LR, X_FIELD, Y_FIELD)
# Out:
# ./utils/logistic_curve.py:23: RuntimeWarning: divide by zero encountered in double_scalars
#   tmp =  [np.power((a-b)/b, 2) for a, b in zip(y_pred, y_test)]
# ./utils/logistic_curve.py:54: RuntimeWarning: invalid value encountered in double_scalars
#   diff = abs(train_error - test_error)
# 624,40.896542221568396,160.10199757399235,18594.21824058098
# DateUS/2020-09-08/Analysis/LogisticRegression/California.jpg

# %%
create_paths("DateUS")
state = "New York"
X_FIELD = "tagged_day"
Y_FIELD = "confirmed"
test_size,diff,sol,train_error,test_error,a,b,c = plot_logistic(state, p.LR, X_FIELD, Y_FIELD)
# Out:
# ./utils/logistic_curve.py:20: RuntimeWarning: overflow encountered in exp
#   return c/(1 + np.exp(-(x-b)/a))
# /Users/zhousicheng/Projects/anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:808: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# 225,12.539217182169642,44.413782608751696,403915.2126721481
# DateUS/2020-09-08/Analysis/LogisticRegression/New York.jpg
